# %%
import kNN

# %%
datingDataMat
# Out:
# array([[  4.09200000e+04,   8.32697600e+00,   9.53952000e-01],
#        [  1.44880000e+04,   7.15346900e+00,   1.67390400e+00],
#        [  2.60520000e+04,   1.44187100e+00,   8.05124000e-01],
#        ...,
#        [  2.65750000e+04,   1.06501020e+01,   8.66627000e-01],
#        [  4.81110000e+04,   9.13452800e+00,   7.28045000e-01],
#        [  4.37570000e+04,   7.88260100e+00,   1.33244600e+00]])

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(datingDataMat[:,1], datingDataMat[:, 2])
plt.show()

# %%
numpy.__version__
# Out:
# '1.9.0.dev-7457f15'

# %%
ipython.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-72dbff75bfbf> in <module>()
# ----> 1 ipython.__version__
#
# NameError: name 'ipython' is not defined

# %%
import IPython
print IPython.sys_info()
# Out:
# {'codename': 'Work in Progress',
#  'commit_hash': 'aeeb7f5',
#  'commit_source': 'installation',
#  'default_encoding': 'UTF-8',
#  'ipython_path': '/Library/Python/2.7/site-packages/ipython-2.0.0_dev-py2.7.egg/IPython',
#  'ipython_version': '2.0.0-dev',
#  'os_name': 'posix',
#  'platform': 'Darwin-12.5.0-x86_64-i386-64bit',
#  'sys_executable': '/usr/local/opt/python/bin/python2.7',
#  'sys_platform': 'darwin',
#  'sys_version': '2.7.5 (default, Oct 13 2013, 13:05:22) \n[GCC 4.2.1 Compatible Apple LLVM 5.0 (clang-500.2.75)]'}
